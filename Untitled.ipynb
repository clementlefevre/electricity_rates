# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_stata('data/tempForClement.dta')
df.to_csv('data/dataset1.csv', index=None)

# %%
df_test.columns
# Out:
# Index([u'date2', u'munid', u'tarifa', u'revenue', u'sales', u'user',
#        u'panelid', u'l1', u'l2', u'l3', u'lu1', u'b0', u'b1', u'b2', u'b3',
#        u'b4', u'b5', u'p0', u'p1', u'p2', u'p3', u'p4', u'p5', u'fixedcharge'],
#       dtype='object')

# %%
df_test = df[df['munid']==1001]

# %%
df_test.groupby(['date2','tarifa']).revenue.mean().plot.bar(figsize=(12,12))
